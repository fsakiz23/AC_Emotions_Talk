# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, LSTM, Dense, Dropout, BatchNormalization, Reshape
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
X = np.load('/content/drive/MyDrive/Dataset/X.npy')
Y = np.load('/content/drive/MyDrive/Dataset/Y.npy')

# %%
Y = tf.keras.utils.to_categorical(Y, num_classes=6)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size = 0.75, random_state=2)
print(f"Shape of X Train: {X_train.shape}")
print(f"Shape of Y Train: {Y_train.shape}")
print(f"Shape of X Test: {X_test.shape}")
print(f"Shape of Y Test: {Y_test.shape}")
# Out:
# Shape of X Train: (3521, 128, 128)
# Shape of Y Train: (3521, 6)
# Shape of X Test: (1174, 128, 128)
# Shape of Y Test: (1174, 6)

# %%
def create_model(input_shape, num_classes):
    model = tf.keras.Sequential()

    # CNN Block
    model.add(Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))

    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))

    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(BatchNormalization())
    model.add(MaxPooling2D((2, 2)))

    model.add(Flatten())

    # Dense Layers
    model.add(Dense(64, activation='relu'))
    model.add(Dropout(0.3))
    model.add(Dense(32, activation='relu'))
    model.add(Dropout(0.3))

    # Output Layer
    model.add(Dense(num_classes, activation='softmax'))

    return model

# %%
# Example usage
input_shape = (128, 128, 1)
num_classes = 6
model = create_model(input_shape, num_classes)
model.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_10 (Conv2D)                   │ (None, 126, 126, 32)        │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_6                │ (None, 126, 126, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 63, 63, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 61, 61, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_7                │ (None, 61, 61, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_11 (MaxPooling2D)      │ (None, 30, 30, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_12 (Conv2D)                   │ (None, 28, 28, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_8                │ (None, 28, 28, 128)         │             512 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_12 (MaxPooling2D)      │ (None, 14, 14, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_4 (Flatten)                  │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 64)                  │       1,605,696 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 6)                   │             198 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,701,542 (6.49 MB)
#  Trainable params: 1,701,094 (6.49 MB)
#  Non-trainable params: 448 (1.75 KB)

# %%
from tensorflow.keras import backend as K

def f1_score(y_true, y_pred):
    y_pred = K.round(y_pred)  # Round predictions to 0 or 1
    tp = K.sum(K.cast(y_true * y_pred, 'float'), axis=0)
    fp = K.sum(K.cast((1 - y_true) * y_pred, 'float'), axis=0)
    fn = K.sum(K.cast(y_true * (1 - y_pred), 'float'), axis=0)

    precision = tp / (tp + fp + K.epsilon())
    recall = tp / (tp + fn + K.epsilon())

    f1 = 2 * (precision * recall) / (precision + recall + K.epsilon())
    return K.mean(f1)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
    loss='categorical_crossentropy',  # Use 'sparse_categorical_crossentropy' if labels are not one-hot encoded
    metrics=['accuracy', f1_score]
)

# %%
history = model.fit(X_train, Y_train, validation_data=(X_test, Y_test), epochs=100, batch_size=64)
# Out:
# Epoch 1/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 14s 137ms/step - accuracy: 0.2286 - f1_score: 0.0738 - loss: 2.6552 - val_accuracy: 0.2181 - val_f1_score: 0.0292 - val_loss: 3.4778
# Epoch 2/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2395 - f1_score: 0.0064 - loss: 1.7696 - val_accuracy: 0.1218 - val_f1_score: 0.0459 - val_loss: 5.9157
# Epoch 3/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2360 - f1_score: 0.0000e+00 - loss: 1.7657 - val_accuracy: 0.1082 - val_f1_score: 0.0428 - val_loss: 6.1907
# Epoch 4/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2498 - f1_score: 4.7565e-04 - loss: 1.7557 - val_accuracy: 0.1440 - val_f1_score: 0.0611 - val_loss: 5.1253
# Epoch 5/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2481 - f1_score: 0.0049 - loss: 1.7424 - val_accuracy: 0.1431 - val_f1_score: 0.0538 - val_loss: 4.1691
# Epoch 6/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2485 - f1_score: 0.0032 - loss: 1.7460 - val_accuracy: 0.1584 - val_f1_score: 0.0211 - val_loss: 2.8189
# Epoch 7/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2334 - f1_score: 0.0029 - loss: 1.7457 - val_accuracy: 0.1942 - val_f1_score: 0.0000e+00 - val_loss: 1.9114
# Epoch 8/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2328 - f1_score: 0.0015 - loss: 1.7399 - val_accuracy: 0.2291 - val_f1_score: 0.0000e+00 - val_loss: 1.7679
# Epoch 9/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2443 - f1_score: 0.0031 - loss: 1.7408 - val_accuracy: 0.2411 - val_f1_score: 0.0011 - val_loss: 1.7398
# Epoch 10/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2565 - f1_score: 0.0114 - loss: 1.7291 - val_accuracy: 0.2479 - val_f1_score: 0.0084 - val_loss: 1.7265
# Epoch 11/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - accuracy: 0.2537 - f1_score: 0.0081 - loss: 1.7354 - val_accuracy: 0.2479 - val_f1_score: 0.0000e+00 - val_loss: 1.7231
# Epoch 12/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2299 - f1_score: 0.0028 - loss: 1.7375 - val_accuracy: 0.2487 - val_f1_score: 0.0016 - val_loss: 1.7205
# Epoch 13/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2355 - f1_score: 0.0022 - loss: 1.7377 - val_accuracy: 0.2470 - val_f1_score: 0.0031 - val_loss: 1.7192
# Epoch 14/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2329 - f1_score: 0.0013 - loss: 1.7345 - val_accuracy: 0.2479 - val_f1_score: 0.0000e+00 - val_loss: 1.7190
# Epoch 15/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2416 - f1_score: 3.5237e-04 - loss: 1.7377 - val_accuracy: 0.2572 - val_f1_score: 0.0158 - val_loss: 1.7077
# Epoch 16/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2436 - f1_score: 0.0151 - loss: 1.7249 - val_accuracy: 0.2479 - val_f1_score: 0.0000e+00 - val_loss: 1.7186
# Epoch 17/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2555 - f1_score: 0.0024 - loss: 1.7294 - val_accuracy: 0.2470 - val_f1_score: 0.0000e+00 - val_loss: 1.7187
# Epoch 18/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2435 - f1_score: 0.0042 - loss: 1.7215 - val_accuracy: 0.2513 - val_f1_score: 0.0069 - val_loss: 1.7127
# Epoch 19/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2457 - f1_score: 0.0153 - loss: 1.7326 - val_accuracy: 0.2496 - val_f1_score: 0.0000e+00 - val_loss: 1.7166
# Epoch 20/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2441 - f1_score: 0.0052 - loss: 1.7226 - val_accuracy: 0.2479 - val_f1_score: 0.0000e+00 - val_loss: 1.7178
# Epoch 21/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2312 - f1_score: 0.0012 - loss: 1.7360 - val_accuracy: 0.2479 - val_f1_score: 0.0000e+00 - val_loss: 1.7167
# Epoch 22/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2404 - f1_score: 0.0019 - loss: 1.7342 - val_accuracy: 0.2504 - val_f1_score: 0.0026 - val_loss: 1.7140
# Epoch 23/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2452 - f1_score: 0.0054 - loss: 1.7263 - val_accuracy: 0.2487 - val_f1_score: 0.0000e+00 - val_loss: 1.7164
# Epoch 24/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2387 - f1_score: 0.0051 - loss: 1.7289 - val_accuracy: 0.2470 - val_f1_score: 0.0030 - val_loss: 1.7133
# Epoch 25/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2402 - f1_score: 0.0158 - loss: 1.7403 - val_accuracy: 0.2479 - val_f1_score: 0.0000e+00 - val_loss: 1.7164
# Epoch 26/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2400 - f1_score: 0.0019 - loss: 1.7379 - val_accuracy: 0.2479 - val_f1_score: 0.0000e+00 - val_loss: 1.7160
# Epoch 27/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2428 - f1_score: 0.0011 - loss: 1.7275 - val_accuracy: 0.2479 - val_f1_score: 0.0000e+00 - val_loss: 1.7161
# Epoch 28/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2383 - f1_score: 0.0011 - loss: 1.7306 - val_accuracy: 0.2504 - val_f1_score: 0.0046 - val_loss: 1.7101
# Epoch 29/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2386 - f1_score: 0.0135 - loss: 1.7268 - val_accuracy: 0.2555 - val_f1_score: 0.0101 - val_loss: 1.7047
# Epoch 30/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2507 - f1_score: 0.0166 - loss: 1.7245 - val_accuracy: 0.2538 - val_f1_score: 0.0084 - val_loss: 1.7076
# Epoch 31/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2447 - f1_score: 0.0164 - loss: 1.7209 - val_accuracy: 0.2615 - val_f1_score: 0.0186 - val_loss: 1.7030
# Epoch 32/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - accuracy: 0.2596 - f1_score: 0.0226 - loss: 1.7153 - val_accuracy: 0.2504 - val_f1_score: 0.0076 - val_loss: 1.7113
# Epoch 33/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2646 - f1_score: 0.0244 - loss: 1.7089 - val_accuracy: 0.2743 - val_f1_score: 0.0435 - val_loss: 1.7167
# Epoch 34/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2711 - f1_score: 0.0418 - loss: 1.7098 - val_accuracy: 0.2572 - val_f1_score: 0.0131 - val_loss: 1.6983
# Epoch 35/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2558 - f1_score: 0.0223 - loss: 1.7105 - val_accuracy: 0.2624 - val_f1_score: 0.0180 - val_loss: 1.6928
# Epoch 36/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2609 - f1_score: 0.0373 - loss: 1.7016 - val_accuracy: 0.2504 - val_f1_score: 0.0032 - val_loss: 1.7133
# Epoch 37/100
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.2645 - f1_score: 0.0235 - loss: 1.7117 - val_accuracy: 0.2624 - val_f1_score: 0.0166 - val_loss: 1.6873
# Epoch 38/100
